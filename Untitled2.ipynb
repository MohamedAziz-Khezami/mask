# %%
import numpy as np
from PIL import Image
from io import BytesIO

from PIL import Image
import numpy as np



# Dimensions de l'image
H, W = 720, 720

# Création d'une image blanche (masque binaire)
binary_mask = np.ones((H, W), dtype=np.uint8) * 255

# Coordonnées des objets détectés (x_min, y_min, x_max, y_max)
#bounding_boxes = np.array([
#    [4394, 2078, 5049, 3168],  # Le plus à gauche
#    [5576, 1760, 6776, 3800],  # Milieu
#    [7598, 1612, 8157, 3509]   # Le plus à droite
#])



# Localisation estimée des fenêtres en fonction de l'image
bounding_boxes = np.array([
         [410,161,718,587],
         [156,284,215,456],
         [412,162,719,452]
 ])

# Appliquer le masque binaire sur les fenêtres détectées
for x_min, y_min, x_max, y_max in bounding_boxes:
    binary_mask[y_min:y_max, x_min:x_max] = 0

# Convertir le masque en image et l'afficher
binary_mask_pil = Image.fromarray(binary_mask)
binary_mask_pil.show()

# Retourner l'image binaire
mask_binary_buffer.getvalue()
# Out:
# <PIL.Image.Image image mode=L size=720x720>
# ...
